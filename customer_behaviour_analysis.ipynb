# %%
import pandas as pd 
df = pd.read_csv('customer_shopping_behaviour.csv')

# %%
# !pip install pandas

# %%
import pandas as pd 
df = pd.read_csv('customer_shopping_behaviour.csv')

# %%
df.head()
# Out:
#    Customer_ID  Age  Gender     Category  Quantity  Unit_Price  Total_Amount  \
# 0            1   20  Female  Electronics         5         491          2455
# 1            2   59  Female       Beauty         2         297           594
# 2            3   21    Male  Electronics         5         336          1680
# 3            4   45  Female         Home         5         118           590
# 4            5   30  Female         Home         2         460           920
#
#    Payment_Method  Satisfaction_Score Purchased_AI_Recommendation
# 0            Cash                   1                          No
# 1            Card                   4                          No
# 2            Cash                   3                         Yes
# 3  Digital Wallet                   1                          No
# 4  Digital Wallet                   4                          No

# %%
df.describe(include='all')
# Out:
#         Customer_ID          Age  Gender Category     Quantity   Unit_Price  \
# count   1000.000000  1000.000000    1000     1000  1000.000000  1000.000000
# unique          NaN          NaN       2        6          NaN          NaN
# top             NaN          NaN  Female   Sports          NaN          NaN
# freq            NaN          NaN     506      180          NaN          NaN
# mean     500.500000    41.428000     NaN      NaN     3.061000   252.882000
# std      288.819436    14.131047     NaN      NaN     1.388959   142.213976
# min        1.000000    18.000000     NaN      NaN     1.000000    10.000000
# 25%      250.750000    29.000000     NaN      NaN     2.000000   129.000000
# 50%      500.500000    42.000000     NaN      NaN     3.000000   252.000000
# 75%      750.250000    54.000000     NaN      NaN     4.000000   376.000000
# max     1000.000000    65.000000     NaN      NaN     5.000000   500.000000
#
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID                    0
# Age                            0
# Gender                         0
# Category                       0
# Quantity                       0
# Unit_Price                     0
# Total_Amount                   0
# Payment_Method                 0
# Satisfaction_Score             0
# Purchased_AI_Recommendation    0
# dtype: int64

# %%
#lowercase remove
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'category', 'quantity', 'unit_price',
#        'total_amount', 'payment_method', 'satisfaction_score',
#        'purchased_ai_recommendation'],
#       dtype='object')

# %%
#create age group
labels= ['young','Adult','Middle-aged','Senior']
df['age_group'] = pd.qcut(df['age'], q=4, labels= labels)

# %%
df[['age','age_group']].head(20)
# Out:
#     age    age_group
# 0    20        young
# 1    59       Senior
# 2    21        young
# 3    45  Middle-aged
# 4    30        Adult
# 5    65       Senior
# 6    65       Senior
# 7    22        young
# 8    55       Senior
# 9    29        young
# 10   59       Senior
# 11   18        young
# 12   31        Adult
# 13   46  Middle-aged
# 14   65       Senior
# 15   36        Adult
# 16   34        Adult
# 17   41        Adult
# 18   24        young
# 19   43  Middle-aged

# %%
pip install pysocopg2-binary sqlalchemy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pysocopg2-binary (from versions: none)
# ERROR: No matching distribution found for pysocopg2-binary
# WARNING: You are using pip version 21.1.1; however, version 26.0.1 is available.
# You should consider upgrading via the 'c:\users\dilum\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import sys 
print (sys.version)
print(sys.executable)
# Out:
# 3.9.5 (tags/v3.9.5:0a7dcbd, May  3 2021, 17:27:52) [MSC v.1928 64 bit (AMD64)]
# c:\users\dilum\appdata\local\programs\python\python39\python.exe

# %%
# %pip install --upgrade pip
# Out:
# ...
#
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 21.1.1
#     Uninstalling pip-21.1.1:
#       Successfully uninstalled pip-21.1.1
# ...

# %%
import pandas as pd

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [112 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib.win-amd64-cpython-39\greenlet
#   copying src\greenlet\__init__.py -> build\lib.win-amd64-cpython-39\greenlet
#   creating build\lib.win-amd64-cpython-39\greenlet\platform
#   copying src\greenlet\platform\__init__.py -> build\lib.win-amd64-cpython-39\greenlet\platform
#   creating build\lib.win-amd64-cpython-39\greenlet\tests
#   copying src\greenlet\tests\fail_clearing_run_switches.py -> build\lib.win-amd64-cpython-39\greenlet\tests
#   copying src\greenlet\tests\fail_cpp_exception.py -> build\lib.win-amd64-cpython-39\greenlet\tests
#   copying src\greenlet\tests\fail_initialstub_already_started.py -> build\lib.win-amd64-cpython-39\greenlet\tests
#   copying src\greenlet\tests\fail_slp_switch.py -> build\lib.win-amd64-cpython-39\greenlet\tests
# ...

# %%
import pandas as pd

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
#   Using cached psycopg2_binary-2.9.12-cp39-cp39-win_amd64.whl.metadata (5.1 kB)
# ...
#   Using cached sqlalchemy-2.0.51-cp39-cp39-win_amd64.whl.metadata (9.8 kB)
# ...
#   Using cached greenlet-3.2.5.tar.gz (191 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Using cached psycopg2_binary-2.9.12-cp39-cp39-win_amd64.whl (2.8 MB)
# Using cached sqlalchemy-2.0.51-cp39-cp39-win_amd64.whl (2.1 MB)
# ...
# Failed to build greenlet
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [112 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib.win-amd64-cpython-39\greenlet
# ...

# %%
# %pip install psycopg2-binary sqlalchemy pandas
# Out:
# ...
#
#   Using cached psycopg2_binary-2.9.12-cp39-cp39-win_amd64.whl.metadata (5.1 kB)
# ...
#   Using cached sqlalchemy-2.0.51-cp39-cp39-win_amd64.whl.metadata (9.8 kB)
# ...
#   Using cached greenlet-3.2.5.tar.gz (191 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Using cached psycopg2_binary-2.9.12-cp39-cp39-win_amd64.whl (2.8 MB)
# Using cached sqlalchemy-2.0.51-cp39-cp39-win_amd64.whl (2.1 MB)
# ...
# Failed to build greenlet
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [112 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib.win-amd64-cpython-39\greenlet
#   copying src\greenlet\__init__.py -> build\lib.win-amd64-cpython-39\greenlet
# ...

# %%
# %pip install --upgrade pip setuptools wheel
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %%
import pandas

# %%
print(pandas)
# Out:
# <module 'pandas' from 'c:\\users\\dilum\\appdata\\local\\programs\\python\\python39\\lib\\site-packages\\pandas\\__init__.py'>

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
#   Using cached psycopg2_binary-2.9.12-cp39-cp39-win_amd64.whl.metadata (5.1 kB)
# ...
#   Using cached sqlalchemy-2.0.51-cp39-cp39-win_amd64.whl.metadata (9.8 kB)
# ...
#   Using cached greenlet-3.2.5.tar.gz (191 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Using cached psycopg2_binary-2.9.12-cp39-cp39-win_amd64.whl (2.8 MB)
# Using cached sqlalchemy-2.0.51-cp39-cp39-win_amd64.whl (2.1 MB)
# ...
# Failed to build greenlet
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [112 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib.win-amd64-cpython-39\greenlet
# ...

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install psycopg[binary]
# Out:
# ...
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.9 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.9 MB 1.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.3/2.9 MB 2.3 MB/s eta 0:00:01
#    ------------------------- -------------- 1.8/2.9 MB 2.6 MB/s eta 0:00:01
#    -------------------------------- ------- 2.4/2.9 MB 2.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.6/2.9 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 2.1 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/2 [psycopg-binary]
#    -------------------- ------------------- 1/2 [psycopg]
#    -------------------- ------------------- 1/2 [psycopg]
#    -------------------- ------------------- 1/2 [psycopg]
#    -------------------- ------------------- 1/2 [psycopg]
#    -------------------- ------------------- 1/2 [psycopg]
# ...

# %%
# %pip install SQLAlchemy
# Out:
# ...
#   Using cached sqlalchemy-2.0.51-cp39-cp39-win_amd64.whl.metadata (9.8 kB)
# ...
#   Using cached greenlet-3.2.5.tar.gz (191 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Using cached sqlalchemy-2.0.51-cp39-cp39-win_amd64.whl (2.1 MB)
# ...
# Failed to build greenlet
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [112 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build\lib.win-amd64-cpython-39\greenlet
#   copying src\greenlet\__init__.py -> build\lib.win-amd64-cpython-39\greenlet
#   creating build\lib.win-amd64-cpython-39\greenlet\platform
# ...

# %%
# %pip --version
# Out:
# pip 26.0.1 from c:\users\dilum\appdata\local\programs\python\python39\lib\site-packages\pip (python 3.9)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install SQLAlchemy --only-binary=:all:
# Out:
# ...
#
#   Using cached sqlalchemy-2.0.51-cp39-cp39-win_amd64.whl.metadata (9.8 kB)
# ...
# Using cached sqlalchemy-2.0.51-cp39-cp39-win_amd64.whl (2.1 MB)
# ...
#
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
#    -------------------- ------------------- 1/2 [SQLAlchemy]
# ...

# %%
from sqlalchemy import create_engine

# %%
from sqlalchemy import create_engine

# %%
from sqlalchemy import create_engine

username = "postgres"
password = "Dilum2002"
host = "localhost"
port = "5432"
database = "customer_behaviour_analysis"

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

table_name = "customer"
df.to_sql(table_name, engine, is_exists="replace", index=False)

print(f"data succesfuly loaded into table '{table_name}' in database '{databse}'.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 9
#       6 port = "5432"
#       7 database = "customer_behaviour_analysis"
# ----> 9 engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")
#      11 table_name = "customer"
#      12 df.to_sql(table_name, engine, is_exists="replace", index=False)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File c:\users\dilum\appdata\local\programs\python\python39\lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# ...

# %%
# %pip install psycopg2-binary
# Out:
# ...
#   Using cached psycopg2_binary-2.9.12-cp39-cp39-win_amd64.whl.metadata (5.1 kB)
# Using cached psycopg2_binary-2.9.12-cp39-cp39-win_amd64.whl (2.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

username = "postgres"
password = "Dilum2002"
host = "localhost"
port = "5432"
database = "customer_behaviour_analysis"

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

table_name = "customer"
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"data succesfuly loaded into table '{table_name}' in database '{databse}'.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       9 engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")
#      11 table_name = "customer"
# ---> 12 df.to_sql(table_name, engine, if_exists="replace", index=False)
#      14 print(f"data succesfuly loaded into table '{table_name}' in database '{databse}'.")
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
from sqlalchemy import create_engine

# Read CSV
df = pd.read_csv("customer_shopping_behaviour.csv")

# PostgreSQL credentials
username = "postgres"
password = "your_password"
host = "localhost"
port = "5432"
database = "customer_behaviour_analysis"

# Create engine
engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# Upload to PostgreSQL
table_name = "customer"

df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\users\dilum\appdata\local\programs\python\python39\lib\site-packages\sqlalchemy\engine\base.py:144, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 try:
# --> 144     self._dbapi_connection = engine.raw_connection()
#     145 except dialect.loaded_dbapi.Error as err:
#
# File c:\users\dilum\appdata\local\programs\python\python39\lib\site-packages\sqlalchemy\engine\base.py:3319, in Engine.raw_connection(self)
#    3298 """Return a "raw" DBAPI connection from the connection pool.
#    3299
#    3300 The returned object is a proxied version of the DBAPI
#    (...)
#    3317
#    3318 """
# -> 3319 return self.pool.connect()
#
# File c:\users\dilum\appdata\local\programs\python\python39\lib\site-packages\sqlalchemy\pool\base.py:448, in Pool.connect(self)
# ...

# %%
from sqlalchemy import create_engine

username = "postgres"
password = "Dilum2002"
host = "localhost"
port = "5432"
database = "customer_behaviour_analysis"

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

table_name = "customer"
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"data succesfuly loaded into table '{table_name}' in database '{database}'.")
# Out:
# data succesfuly loaded into table 'customer' in database 'customer_behaviour_analysis'.
